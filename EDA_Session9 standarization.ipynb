# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('C:\\Users\\Pranjali\\Downloads\\Visadataset - Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
round(visa_df['prevailing_wage'].mean(),2)
# Out:
# 74455.81

# %%
numer=visa_df['prevailing_wage']-round(visa_df['prevailing_wage'].mean(),2)
numer
# Out:
# 0        -73863.6071
# 1          8969.8400
# 2         48541.0500
# 3          8978.2200
# 4         75451.5800
#             ...
# 25475      2636.7600
# 25476    204718.9800
# 25477     71843.0400
# 25478     11698.9600
# 25479     -3578.9000
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
std1=visa_df['prevailing_wage'].std
std1
# Out:
# <bound method Series.std of 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64>

# %%
div=numer/std1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 div=numer/std1
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# ...

# %%
visa_df=pd.read_csv('C:\\Users\\Pranjali\\Downloads\\Visadataset - Visadataset.csv')
mean=visa_df['prevailing_wage'].mean()
std=visa_df['prevailing_wage'].std()
nr=visa_df['prevailing_wage']-mean
visa_df['prevailing_wage_z']=nr/std
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv('C:\\Users\\Pranjali\\Downloads\\Visadataset - Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])

# %% [markdown]
# **Normalization**

# %%
visa_df=pd.read_csv('C:\\Users\\Pranjali\\Downloads\\Visadataset - Visadataset.csv')
visa_df['prevailing_wage']
min=visa_df['prevailing_wage'].min()
max=visa_df['prevailing_wage'].max()
nr=visa_df['prevailing_wage']-min
diff=max-min
visa_df['prevailing_wage_n']=nr/diff
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
maxx=visa_df['prevailing_wage'].idmax(),visa_df[prevailing_wage_n'].idmax()

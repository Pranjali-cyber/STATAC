# %%
a=1
b=2
c=a+b
c
# Out:
# 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('C:\\Users\\Pranjali\\Downloads\\Visadataset - Visadataset.csv')
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(visa_df['prevailing_wage'],orient='h')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2135aa6ced0>,
#   <matplotlib.lines.Line2D at 0x2135aa6da90>],
#  'caps': [<matplotlib.lines.Line2D at 0x2135aa6e610>,
#   <matplotlib.lines.Line2D at 0x2135aa6f1d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2135aa6c290>],
#  'medians': [<matplotlib.lines.Line2D at 0x2135aa6fc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2135aa74710>],
#  'means': []}

# %%
Q1=round(np.quantile(visa_df['prevailing_wage'],0.25),2)
Q3=round(np.quantile(visa_df['prevailing_wage'],0.75),2)

# %%
iqr=Q3-Q1
print(iqr)
# Out:
# 73720.03

# %%
LB=Q1-1.5*iqr
LB
# Out:
# -76564.565

# %%
UB=Q3+1.5*iqr
UB
# Out:
# 218315.555

# %%
con1=visa_df['prevailing_wage']<LB
con2=visa_df['prevailing_wage']>UB
outliers=visa_df[con1|con2]

# %%
len(outliers)
# Out:
# 427

# %%
Q1=round(np.percentile(visa_df['prevailing_wage'],25),2)
Q3=round(np.percentile(visa_df['prevailing_wage'],75),2)
iqr=Q3-Q1
LB=Q1-1.5*iqr
UB=Q3+1.5*iqr
con1=visa_df['prevailing_wage']<LB
con2=visa_df['prevailing_wage']>UB
non_outliers=visa_df[con1 & con2]
len(non_outliers)
# Out:
# 0

# %%
l1=[]
mediann=visa_df['prevailing_wage'].median()
values=visa_df['prevailing_wage'].values
Q1=(np.percentile(visa_df['prevailing_wage'],25))
Q3=(np.percentile(visa_df['prevailing_wage'],75))
lb=Q1-1.5*iqr
ub=Q3+1.5*iqr
for value in visa_df['prevailing_wage'].values:
    if value<lb or value>ub:
        l1.append(mediann)
    else:
        l1.append(value)
visa_df_copy=visa_df.copy 
visa_df_copy['prevailing_wage']=l1
plt.subplot(1,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 14
#      12         l1.append(value)
#      13 visa_df_copy=visa_df.copy
# ---> 14 visa_df_copy['prevailing_wage']=l1
#      15 plt.subplot(1,2,1).hist(visa_df['prevailing_wage'])
#      16 plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage'])
#
# TypeError: 'method' object does not support item assignment

# %%
con1=visa_df['prevailing_wage']>lb 
con2=visa_df['prevailing_wage']<ub
